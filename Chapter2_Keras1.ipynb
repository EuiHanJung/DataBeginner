# %% [markdown]
# <a href="https://colab.research.google.com/github/EuiHanJung/DataBeginner/blob/main/Chapter2_Keras1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2장 텐서플로우 _ 캐라스
#
# Keras (Sequential model)를 사용한 버전
#
# x, y 데이터 세트가 있을 때, 이차 방정식 y = w1x^2 + w2x + b를 만족하는
# parameter w1, w2, b를 추정한다.

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
import numpy as np
import matplotlib.pyplot as plt

# y = 2x^2 + 3x + 5 일 때 x, y 집합을 생성한다
x = np.array(np.arange(-5, 5, 0.1))
y = 2 * x * x + 3 * x + 5
dataX = np.stack([x*x, x]).T

# %%
# 그래프를 생성한다.
model = Sequential()
model.add(Dense(1, input_dim = 2)) 
model.compile(loss='mse', optimizer=optimizers.RMSprop(lr=0.05))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
# 학습한다.
h = model.fit(dataX, y, batch_size = 10, epochs = 300)
# Out:
# Epoch 1/300
# 10/10 [==============================] - 1s 2ms/step - loss: 80.9360
# Epoch 2/300
# 10/10 [==============================] - 0s 1ms/step - loss: 20.3381
# Epoch 3/300
# 10/10 [==============================] - 0s 1ms/step - loss: 9.2072
# Epoch 4/300
# 10/10 [==============================] - 0s 1ms/step - loss: 6.1800
# Epoch 5/300
# 10/10 [==============================] - 0s 1ms/step - loss: 4.6967
# Epoch 6/300
# 10/10 [==============================] - 0s 1ms/step - loss: 3.6336
# Epoch 7/300
# 10/10 [==============================] - 0s 1ms/step - loss: 2.8244
# Epoch 8/300
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9613
# Epoch 9/300
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3397
# Epoch 10/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9278
# Epoch 11/300
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5106
# Epoch 12/300
# ...

# %%
# 학습 결과를 확인한다.
parameters = model.layers[0].get_weights()
print("\n추정 결과 :")
print("w1 = %.2f" % parameters[0][0][0])
print("w2 = %.2f" % parameters[0][1][0])
print("b = %.2f" % parameters[1][0])
# Out:
# 추정 결과 :
# w1 = 2.06
# w2 = 2.97
# b = 5.07

# %%
plt.plot(h.history['loss'], color='red', linewidth=1)
plt.title("Loss function")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()
